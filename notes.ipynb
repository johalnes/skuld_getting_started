# %%
import duckdb
import polars as pl
import numpy as np
#import chainladder as cl

# %% [markdown]
# ## Final Polars version

# %%
def calculate_cl_factors(
    amount: str = "paid_claims_usd",
    development: str = "development_lag",
    origin="accident_date",
) -> pl.Expr:
    # list concatinated, not list in list
    sort_cols = [origin, development]
    over_cols = [origin]
    # Calculate  Chain-Ladder Factors, simple and volume-weighted with Polars
    return (
        pl.col(amount).sort_by(sort_cols).pct_change().over(over_cols).fill_null(0) + 1
    )


def calculate_cdf(ldf: str = "ldf_incurred", development: str = "development_lag"):
    cdf = pl.col(ldf).sort_by(development, descending=True).shift(1,fill_value=1).cum_prod()
    return cdf.reverse()


def calculate_factors(df, index, development, origin):
    dataframes = []

    for df_lob in df.partition_by("line_of_business"):
        df_factors = (
            df_lob
            .with_columns(
                cl_factor_incurred=calculate_cl_factors(amount="incurred_claims_usd"),
                cl_factor_paid=calculate_cl_factors(amount="paid_claims_usd"),
            )
            .group_by([index, development])
            .agg(
                ldf_incurred=pl.col("cl_factor_incurred").mean(),
                ldf_paid=pl.col("cl_factor_paid").mean(),
            )
            .sort(development)
            .with_columns(
                cdf_incurred=calculate_cdf("ldf_incurred"),
                cdf_paid=calculate_cdf("ldf_paid"),
            )
        )
        dataframes.append(df_factors)
    return pl.concat(dataframes)


with duckdb.connect("./data/db_dev.duckdb") as con:
    df = con.execute(
        "SELECT line_of_business,accident_date, accident_year, development_year, development_lag, incurred_claims_usd, paid_claims_usd FROM report_ibnr"
    ).pl()

dev_years = df.select(pl.col("development_year").unique().sort()).to_series()
df_dev = pl.concat(
    [
        (
            df.with_columns(
                cl_factor_incurred=calculate_cl_factors(amount="incurred_claims_usd"),
                cl_factor_paid=calculate_cl_factors(amount="paid_claims_usd"),
            )
            .filter(pl.col("line_of_business") == "Workers' compensation insurance")
            .filter(pl.col("development_year") <= dev_year)
            .pipe(
                calculate_factors, index="line_of_business", development="development_lag", origin="accident_date"
            )
        )
        for dev_year in [1997]
    ]
)
df_dev.sort(["line_of_business","development_lag"])
# Out:
# shape: (10, 6)
# ┌───────────────────────┬─────────────────┬──────────────┬──────────┬──────────────┬──────────┐
# │ line_of_business      ┆ development_lag ┆ ldf_incurred ┆ ldf_paid ┆ cdf_incurred ┆ cdf_paid │
# │ ---                   ┆ ---             ┆ ---          ┆ ---      ┆ ---          ┆ ---      │
# │ str                   ┆ i64             ┆ f64          ┆ f64      ┆ f64          ┆ f64      │
# ╞═══════════════════════╪═════════════════╪══════════════╪══════════╪══════════════╪══════════╡
# │ Workers' compensation ┆ 0               ┆ 1.0          ┆ 1.0      ┆ 0.967007     ┆ 4.122531 │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 1               ┆ 1.023213     ┆ 2.206679 ┆ 0.94507      ┆ 1.868206 │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 2               ┆ 0.975516     ┆ 1.316287 ┆ 0.96879      ┆ 1.4193   │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 3               ┆ 0.981517     ┆ 1.149941 ┆ 0.987033     ┆ 1.234237 │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 4               ┆ 0.996586     ┆ 1.081418 ┆ 0.990414     ┆ 1.141314 │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 5               ┆ 0.996526     ┆ 1.046461 ┆ 0.993867     ┆ 1.090642 │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 6               ┆ 0.997014     ┆ 1.032269 ┆ 0.996843     ┆ 1.056548 │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 7               ┆ 1.000317     ┆ 1.02525  ┆ 0.996527     ┆ 1.030528 │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 8               ┆ 1.000575     ┆ 1.020144 ┆ 0.995955     ┆ 1.010179 │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# │ Workers' compensation ┆ 9               ┆ 0.995955     ┆ 1.010179 ┆ 1.0          ┆ 1.0      │
# │ insurance             ┆                 ┆              ┆          ┆              ┆          │
# └───────────────────────┴─────────────────┴──────────────┴──────────┴──────────────┴──────────┘

# %%
df.partition_by

# %%
df_dev.with_columns(cdf = calculate_cdf(ldf="ldf_incurred"))
# Out:
# /tmp/ipykernel_1056/3578148249.py:17: DeprecationWarning: `cumprod` is deprecated. It has been renamed to `cum_prod`.
#   cdf = pl.col(ldf).sort_by([index, development], descending=True).cumprod().over(index)
# shape: (10, 6)
# ┌───────────────────────┬─────────────────┬──────────────┬──────────┬──────────┬──────────┐
# │ line_of_business      ┆ development_lag ┆ ldf_incurred ┆ ldf_paid ┆ dev_year ┆ cdf      │
# │ ---                   ┆ ---             ┆ ---          ┆ ---      ┆ ---      ┆ ---      │
# │ str                   ┆ i64             ┆ f64          ┆ f64      ┆ i32      ┆ f64      │
# ╞═══════════════════════╪═════════════════╪══════════════╪══════════╪══════════╪══════════╡
# │ Workers' compensation ┆ 0               ┆ 1.0          ┆ 1.0      ┆ 1997     ┆ 0.967007 │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 4               ┆ 0.996586     ┆ 1.081418 ┆ 1997     ┆ 0.967007 │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 7               ┆ 1.000317     ┆ 1.02525  ┆ 1997     ┆ 0.94507  │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 1               ┆ 1.023213     ┆ 2.206679 ┆ 1997     ┆ 0.96879  │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 2               ┆ 0.975516     ┆ 1.316287 ┆ 1997     ┆ 0.987033 │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 3               ┆ 0.981517     ┆ 1.149941 ┆ 1997     ┆ 0.990414 │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 5               ┆ 0.996526     ┆ 1.046461 ┆ 1997     ┆ 0.993867 │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 6               ┆ 0.997014     ┆ 1.032269 ┆ 1997     ┆ 0.996843 │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 8               ┆ 1.000575     ┆ 1.020144 ┆ 1997     ┆ 0.996527 │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# │ Workers' compensation ┆ 9               ┆ 0.995955     ┆ 1.010179 ┆ 1997     ┆ 0.995955 │
# │ insurance             ┆                 ┆              ┆          ┆          ┆          │
# └───────────────────────┴─────────────────┴──────────────┴──────────┴──────────┴──────────┘

# %%
pl.concat([df_group.select(pl.col("cdf_incurred").reverse()) for df_group in df_dev.partition_by("line_of_business")])
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 pl.concat([df_group.select(pl.col("cdf_incurred").reverse()) for df_group in df_dev.partition_by("line_of_business")])
#
# Cell In[83], line 1, in <listcomp>(.0)
# ----> 1 pl.concat([df_group.select(pl.col("cdf_incurred").reverse()) for df_group in df_dev.partition_by("line_of_business")])
#
# File ~/.local/lib/python3.10/site-packages/polars/dataframe/frame.py:8102, in DataFrame.select(self, *exprs, **named_exprs)
#    8002 def select(
#    8003     self, *exprs: IntoExpr | Iterable[IntoExpr], **named_exprs: IntoExpr
#    8004 ) -> DataFrame:
#    8005     """
#    8006     Select columns from this DataFrame.
#    8007
#    (...)
#    8100     └───────────┘
#    8101     """
# -> 8102     return self.lazy().select(*exprs, **named_exprs).collect(_eager=True)
#
# File ~/.local/lib/python3.10/site-packages/polars/lazyframe/frame.py:1943, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, no_optimization, streaming, background, _eager)
#    1940 if background:
#    1941     return InProcessQuery(ldf.collect_concurrently())
# -> 1943 return wrap_df(ldf.collect())
#
# ColumnNotFoundError: cdf_incurred
#
# Error originated just after this operation:
# DF ["line_of_business", "development_lag", "ldf_incurred", "ldf_paid"]; PROJECT */5 COLUMNS; SELECTION: "None"

# %%
df_list = df_dev.group_by("line_of_business").agg(pl.col("development_lag"),
                                                  pl.col("ldf_incurred").sort_by("development_lag").map_elements(cdf_numpy).alias("cdf_incurred"),
                                                  pl.col("ldf_paid").sort_by("development_lag").map_elements(cdf_numpy).alias("cdf_paid"),
                                                  pl.col("ldf_incurred").sort_by("development_lag"),
                                                  ).explode(["development_lag","ldf_incurred","ldf_paid","cdf_incurred","cdf_paid"])
# Out:
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_list = df_dev.group_by("line_of_business").agg(pl.col("development_lag"),
#       2                                                   pl.col("ldf_incurred").sort_by("development_lag").map_elements(cdf_numpy).alias("cdf_incurred"),
#       3                                                   pl.col("ldf_paid").sort_by("development_lag").map_elements(cdf_numpy).alias("cdf_paid"),
#       4                                                   pl.col("ldf_incurred").sort_by("development_lag"),
#       5                                                   ).explode(["development_lag","ldf_incurred","ldf_paid","cdf_incurred","cdf_paid"])
#
# File ~/.local/lib/python3.10/site-packages/polars/dataframe/group_by.py:247, in GroupBy.agg(self, *aggs, **named_aggs)
#     141 def agg(
#     142     self,
#     143     *aggs: IntoExpr | Iterable[IntoExpr],
#     144     **named_aggs: IntoExpr,
#     145 ) -> DataFrame:
#     146     """
#     147     Compute aggregations for each group of a group by operation.
#     148
#    (...)
#     244     └─────┴───────┴────────────────┘
#     245     """
#     246     return (
# --> 247         self.df.lazy()
#     248         .group_by(*self.by, **self.named_by, maintain_order=self.maintain_order)
#     249         .agg(*aggs, **named_aggs)
#     250         .collect(no_optimization=True)
#     251     )
#
# File ~/.local/lib/python3.10/site-packages/polars/lazyframe/frame.py:1943, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, no_optimization, streaming, background, _eager)
#    1940 if background:
#    1941     return InProcessQuery(ldf.collect_concurrently())
# -> 1943 return wrap_df(ldf.collect())
#
# ComputeError: IndexError: invalid index to scalar variable.

# %%
def cdf_numpy(ldf):
    ldf=ldf.to_numpy()[0]
    cdf = ldf[::-1].cumprod()[::-1]
    return cdf

# %%
df_list = df_dev.group_by("line_of_business").agg(pl.col("ldf_incurred")).with_columns(cdf_numpy(pl.col("ldf_incurred")))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df_list = df_dev.group_by("line_of_business").agg(pl.col("ldf_incurred")).with_columns(cdf_numpy(pl.col("ldf_incurred")))
#
# Cell In[5], line 2, in cdf_numpy(ldf)
#       1 def cdf_numpy(ldf):
# ----> 2     ldf=ldf.to_numpy()[0]
#       3     cdf = ldf[::-1].cumprod()[::-1]
#       4     return cdf
#
# AttributeError: 'Expr' object has no attribute 'to_numpy'

# %%
df_list
# Out:
# shape: (1, 2)
# ┌─────────────────────────────────┬─────────────────────────────┐
# │ line_of_business                ┆ ldf_incurred                │
# │ ---                             ┆ ---                         │
# │ str                             ┆ list[f64]                   │
# ╞═════════════════════════════════╪═════════════════════════════╡
# │ Workers' compensation insurance ┆ [1.0, 0.996586, … 0.995955] │
# └─────────────────────────────────┴─────────────────────────────┘

# %%
df_list.group_by("line_of_business").agg(pl.col("ldf_incurred").map_elements(cdf_numpy).alias("cdf"))
# Out:
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# shape: (1, 2)
# ┌─────────────────────────────────┬───────────────────────────────────┐
# │ line_of_business                ┆ cdf                               │
# │ ---                             ┆ ---                               │
# │ str                             ┆ object                            │
# ╞═════════════════════════════════╪═══════════════════════════════════╡
# │ Workers' compensation insurance ┆ [0.96700734 0.96700734 0.9703196… │
# └─────────────────────────────────┴───────────────────────────────────┘

# %%
df_list.get_column("cl_factor_incurred").to_numpy()[0]
# Out:
# array([1.0232127 , 0.98151668, 0.99658636, 0.99652601, 1.00031696,
#        1.        , 0.97551597, 0.9970141 , 1.00057454, 0.99595524])

# %% [markdown]
# ## Chainladder package

# %%
# !pip install chainladder
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting chainladder
#   Downloading chainladder-0.8.18-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.3 MB/s eta 0:00:0000:0100:01m
# Collecting scikit-learn>=0.23
#   Downloading scikit_learn-1.4.1.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 43.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numba>0.54 in /home/vscode/.local/lib/python3.10/site-packages (from chainladder) (0.59.1)
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 49.2 MB/s eta 0:00:0000:0100:01
# Collecting sparse>=0.9
#   Downloading sparse-0.15.1-py2.py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.23 in /home/vscode/.local/lib/python3.10/site-packages (from chainladder) (2.2.1)
# Collecting patsy
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 9.6 MB/s eta 0:00:00
# Collecting dill
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/vscode/.local/lib/python3.10/site-packages (from numba>0.54->chainladder) (0.42.0)
# Requirement already satisfied: numpy<1.27,>=1.22 in /home/vscode/.local/lib/python3.10/site-packages (from numba>0.54->chainladder) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=0.23->chainladder) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=0.23->chainladder) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=0.23->chainladder) (2.9.0.post0)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 21.0 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib->chainladder) (23.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.50.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 41.2 MB/s eta 0:00:0000:01:00:01
# Requirement already satisfied: pillow>=8 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib->chainladder) (10.2.0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib->chainladder) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from matplotlib->chainladder) (3.1.2)
# Requirement already satisfied: six in /home/vscode/.local/lib/python3.10/site-packages (from patsy->chainladder) (1.16.0)
# Installing collected packages: threadpoolctl, scipy, patsy, kiwisolver, joblib, fonttools, dill, cycler, sparse, scikit-learn, matplotlib, chainladder
# Successfully installed chainladder-0.8.18 cycler-0.12.1 dill-0.3.8 fonttools-4.50.0 joblib-1.3.2 kiwisolver-1.4.5 matplotlib-3.8.3 patsy-0.5.6 scikit-learn-1.4.1.post1 scipy-1.12.0 sparse-0.15.1 threadpoolctl-3.4.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import chainladder as cl
test = cl.load_sample('clrd').groupby('LOB').sum()
test
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/pandas.py:415: FutureWarning: DataFrameGroupBy.dtypes is deprecated and will be removed in a future version. Check the dtypes on the base object instead
#   if isinstance(self.groups.dtypes.index, pd.MultiIndex):
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/pandas.py:427: FutureWarning: DataFrameGroupBy.dtypes is deprecated and will be removed in a future version. Check the dtypes on the base object instead
#   index = pd.DataFrame(self.groups.dtypes.index)
#                                              Triangle Summary
# Valuation:                                            1997-12
# Grain:                                                   OYDY
# Shape:                                         (6, 6, 10, 10)
# Index:                                                  [LOB]
# Columns:    [IncurLoss, CumPaidLoss, BulkLoss, EarnedPremD...

# %%
dev = cl.Development(average="simple").fit_transform(test["IncurLoss"])
ibnr = cl.Chainladder().fit(dev["IncurLoss"])
ibnr.ultimate_.to_frame().T
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/utils/weighted_regression.py:58: RuntimeWarning: Mean of empty slice
#   xp.nansum(w * x * y, axis) - xp.nansum(x * w, axis) * xp.nanmean(y, axis)
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/utils/weighted_regression.py:62: RuntimeWarning: Mean of empty slice
#   intercept = xp.nanmean(y, axis) - slope * xp.nanmean(x, axis)
# LOB           comauto         medmal        othliab        ppauto  \
# origin
# 1988    629146.000000  236376.000000  328473.000000  8.723062e+06
# 1989    679231.398324  241107.011377  367994.093378  9.855793e+06
# 1990    728839.971396  270345.278304  396925.632756  1.078618e+07
# 1991    730441.283895  300337.404311  485515.583144  1.080384e+07
# 1992    761066.208582  313435.895437  498677.539336  1.172571e+07
# 1993    816279.244374  330108.675136  563184.660280  1.260404e+07
# 1994    888304.311678  355154.143799  638800.138275  1.341368e+07
# 1995    895392.015550  372686.756583  601429.407051  1.349324e+07
# 1996    872985.851884  364739.366542  680283.721933  1.318495e+07
# 1997    890434.440272  346423.102362  679600.097413  1.299052e+07
#
# LOB          prodliab        wkcomp
# origin
# 1988    123424.000000  1.356500e+06
# 1989    127828.161046  1.451549e+06
# 1990    142673.097646  1.568354e+06
# 1991    126807.537539  1.635776e+06
# 1992    102629.397212  1.594492e+06
# 1993    129251.908274  1.534061e+06
# 1994    148422.276704  1.548814e+06
# 1995    141974.376783  1.564075e+06
# 1996    136922.012916  1.474465e+06
# 1997    127422.559491  1.452841e+06

# %%
ibnr.full_triangle_.loc["wkcomp"]
# Out:
#            12            24            36            48            60            72            84            96            108           120           132           9999
# 1988  1273279.0  1.343238e+06  1.356530e+06  1.351429e+06  1.379353e+06  1.377612e+06  1.363000e+06  1.362205e+06  1.362009e+06  1.356500e+06  1.356500e+06  1.356500e+06
# 1989  1383700.0  1.441224e+06  1.433627e+06  1.472238e+06  1.473424e+06  1.460943e+06  1.458170e+06  1.455562e+06  1.457444e+06  1.451549e+06  1.451549e+06  1.451549e+06
# 1990  1477245.0  1.621324e+06  1.605337e+06  1.602578e+06  1.584751e+06  1.570110e+06  1.568607e+06  1.573819e+06  1.574723e+06  1.568354e+06  1.568354e+06  1.568354e+06
# 1991  1629195.0  1.694048e+06  1.686692e+06  1.661484e+06  1.639743e+06  1.638468e+06  1.640956e+06  1.641476e+06  1.642419e+06  1.635776e+06  1.635776e+06  1.635776e+06
# 1992  1634231.0  1.749947e+06  1.689300e+06  1.621422e+06  1.600524e+06  1.604332e+06  1.599542e+06  1.600049e+06  1.600968e+06  1.594492e+06  1.594492e+06  1.594492e+06
# 1993  1719891.0  1.714687e+06  1.643956e+06  1.556461e+06  1.548909e+06  1.543528e+06  1.538919e+06  1.539407e+06  1.540292e+06  1.534061e+06  1.534061e+06  1.534061e+06
# 1994  1785215.0  1.750992e+06  1.638790e+06  1.569161e+06  1.563804e+06  1.558372e+06  1.553719e+06  1.554211e+06  1.555104e+06  1.548814e+06  1.548814e+06  1.548814e+06
# 1995  1750767.0  1.692856e+06  1.614463e+06  1.584622e+06  1.579213e+06  1.573727e+06  1.569028e+06  1.569525e+06  1.570427e+06  1.564075e+06  1.564075e+06  1.564075e+06
# 1996  1625977.0  1.560165e+06  1.521966e+06  1.493835e+06  1.488735e+06  1.483564e+06  1.479134e+06  1.479603e+06  1.480453e+06  1.474465e+06  1.474465e+06  1.474465e+06
# 1997  1502410.0  1.537285e+06  1.499646e+06  1.471928e+06  1.466903e+06  1.461807e+06  1.457442e+06  1.457904e+06  1.458742e+06  1.452841e+06  1.452841e+06  1.452841e+06

# %%
ibnr.cdf_.loc["wkcomp"]
# Out:
#          12-Ult   24-Ult    36-Ult    48-Ult    60-Ult    72-Ult    84-Ult    96-Ult   108-Ult  120-Ult  132-Ult
# (All)  0.960911  0.94185  0.967099  0.986688  0.990848  0.994258  0.996962  0.996551  0.995955      1.0      1.0

# %%
dev.cdf_.loc["wkcomp"]["IncurLoss"]*test.loc["wkcomp"]["IncurLoss"].latest_diagonal.val_to_dev()
# Out:
#                12            24            36            48            60            72            84            96            108  120
# 1988           NaN           NaN           NaN           NaN           NaN           NaN           NaN           NaN           NaN  NaN
# 1989           NaN           NaN           NaN           NaN           NaN           NaN           NaN           NaN  1.451549e+06  NaN
# 1990           NaN           NaN           NaN           NaN           NaN           NaN           NaN  1.568354e+06           NaN  NaN
# 1991           NaN           NaN           NaN           NaN           NaN           NaN  1.635776e+06           NaN           NaN  NaN
# 1992           NaN           NaN           NaN           NaN           NaN  1.594492e+06           NaN           NaN           NaN  NaN
# 1993           NaN           NaN           NaN           NaN  1.534061e+06           NaN           NaN           NaN           NaN  NaN
# 1994           NaN           NaN           NaN  1.548814e+06           NaN           NaN           NaN           NaN           NaN  NaN
# 1995           NaN           NaN  1.564075e+06           NaN           NaN           NaN           NaN           NaN           NaN  NaN
# 1996           NaN  1.474465e+06           NaN           NaN           NaN           NaN           NaN           NaN           NaN  NaN
# 1997  1.452841e+06           NaN           NaN           NaN           NaN           NaN           NaN           NaN           NaN  NaN

# %%
test.loc["wkcomp"]["IncurLoss"].latest_diagonal
# Out:
#            1997
# 1988  1356500.0
# 1989  1457444.0
# 1990  1573819.0
# 1991  1640956.0
# 1992  1604332.0
# 1993  1548909.0
# 1994  1569161.0
# 1995  1614463.0
# 1996  1560165.0
# 1997  1502410.0

# %%
dev.cdf_.loc["wkcomp"]["IncurLoss"]
# Out:
#          12-Ult   24-Ult   36-Ult    48-Ult    60-Ult    72-Ult    84-Ult    96-Ult   108-Ult
# (All)  0.967007  0.94507  0.96879  0.987033  0.990414  0.993867  0.996843  0.996527  0.995955

# %%
dev.ldf_.loc["wkcomp"].to_frame().sort_index(ascending=False).T["IncurLoss"]
# Out:
# development
# 96-108     1.000575
# 84-96      1.000317
# 72-84      0.997014
# 60-72      0.996526
# 48-60      0.996586
# 36-48      0.981517
# 24-36      0.975516
# 12-24      1.023213
# 108-120    0.995955
# Name: IncurLoss, dtype: float64

# %%
import pandas as pd
fin_ibnr = ibnr.ibnr_.loc["wkcomp"].to_frame()
ldf_dev = dev.ldf_.loc["wkcomp"].to_frame().T["IncurLoss"].to_list()
ldf_dev.reverse()
cdf_dev = dev.cdf_.loc["wkcomp"].to_frame().T["IncurLoss"].to_list()

df_fin_ibnr= fin_ibnr.assign(
    ultimate = ibnr.ultimate_.loc["wkcomp"].to_frame(),
    incurred=test.loc["wkcomp"].latest_diagonal.to_frame().T["IncurLoss"].to_list()
    ).dropna().assign(ldf=ldf_dev, cdf=cdf_dev, test = lambda df_: df_["cdf"]*df_["incurred"])

# %%
ibnr.ultimate_.loc["wkcomp"].to_frame().values
# Out:
# array([[1356500.        ],
#        [1451548.98829597],
#        [1568391.15892512],
#        [1635970.51017018],
#        [1595120.00394135],
#        [1534733.9580067 ],
#        [1548271.72693472],
#        [1561345.4992816 ],
#        [1469441.33580175],
#        [1443681.72281264]])

# %%
dev.cdf_.loc["wkcomp"].to_frame().T["IncurLoss"].to_list()
# Out:
# [0.967007339208989,
#  0.9450697181687259,
#  0.9687895933000701,
#  0.9870332439944216,
#  0.9904141567645723,
#  0.9938668396459205,
#  0.9968433179273872,
#  0.996527459264213,
#  0.9959552396496646]

# %%
ibnr.full_triangle_.loc["wkcomp"]
# Out:
#            12            24            36            48            60            72            84            96            108           120           132           9999
# 1988  1273279.0  1.343238e+06  1.356530e+06  1.351429e+06  1.379353e+06  1.377612e+06  1.363000e+06  1.362205e+06  1.362009e+06  1.356500e+06  1.356500e+06  1.356500e+06
# 1989  1383700.0  1.441224e+06  1.433627e+06  1.472238e+06  1.473424e+06  1.460943e+06  1.458170e+06  1.455562e+06  1.457444e+06  1.451549e+06  1.451549e+06  1.451549e+06
# 1990  1477245.0  1.621324e+06  1.605337e+06  1.602578e+06  1.584751e+06  1.570110e+06  1.568607e+06  1.573819e+06  1.574761e+06  1.568391e+06  1.568391e+06  1.568391e+06
# 1991  1629195.0  1.694048e+06  1.686692e+06  1.661484e+06  1.639743e+06  1.638468e+06  1.640956e+06  1.641632e+06  1.642614e+06  1.635971e+06  1.635971e+06  1.635971e+06
# 1992  1634231.0  1.749947e+06  1.689300e+06  1.621422e+06  1.600524e+06  1.604332e+06  1.599981e+06  1.600640e+06  1.601598e+06  1.595120e+06  1.595120e+06  1.595120e+06
# 1993  1719891.0  1.714687e+06  1.643956e+06  1.556461e+06  1.548909e+06  1.543597e+06  1.539411e+06  1.540045e+06  1.540967e+06  1.534734e+06  1.534734e+06  1.534734e+06
# 1994  1785215.0  1.750992e+06  1.638790e+06  1.569161e+06  1.562572e+06  1.557213e+06  1.552990e+06  1.553630e+06  1.554560e+06  1.548272e+06  1.548272e+06  1.548272e+06
# 1995  1750767.0  1.692856e+06  1.614463e+06  1.582411e+06  1.575766e+06  1.570362e+06  1.566104e+06  1.566749e+06  1.567686e+06  1.561345e+06  1.561345e+06  1.561345e+06
# 1996  1625977.0  1.560165e+06  1.519432e+06  1.489267e+06  1.483013e+06  1.477928e+06  1.473919e+06  1.474527e+06  1.475409e+06  1.469441e+06  1.469441e+06  1.469441e+06
# 1997  1502410.0  1.532815e+06  1.492796e+06  1.463160e+06  1.457016e+06  1.452019e+06  1.448081e+06  1.448678e+06  1.449545e+06  1.443682e+06  1.443682e+06  1.443682e+06

# %%
dev.ldf_.loc["wkcomp"].to_frame().T["IncurLoss"]
# Out:
# development
# 12-24      1.023213
# 24-36      0.975516
# 36-48      0.981517
# 48-60      0.996586
# 60-72      0.996526
# 72-84      0.997014
# 84-96      1.000317
# 96-108     1.000575
# 108-120    0.995955
# Name: IncurLoss, dtype: float64

# %%
dev.cdf_.loc["wkcomp"].to_frame().T["IncurLoss"]
# Out:
# development
# 12-Ult     0.967007
# 24-Ult     0.945070
# 36-Ult     0.968790
# 48-Ult     0.987033
# 60-Ult     0.990414
# 72-Ult     0.993867
# 84-Ult     0.996843
# 96-Ult     0.996527
# 108-Ult    0.995955
# Name: IncurLoss, dtype: float64

# %%
import chainladder as cl
import pandas as pd

triangle = cl.Triangle(
    df,
    origin="accident_date",
    development="development_date",
    index="line_of_business",
    columns=[
        "incremental_paid_claims_usd"
    ],
    grain="oydy",
    cumulative=True
)
dev = cl.TweedieGLM(
    design_matrix="C(line_of_business) + C(development) + C(origin)", link="log", power=1
).fit(triangle)

# Grab LDFs vs traditional approach
glm = dev.ldf_.iloc[..., 0, :].T.iloc[:, 0].rename("GLM")
traditional = cl.Development().fit(triangle).ldf_.T.iloc[:, 0].rename("Traditional")

# Plot data
results = pd.concat((glm, traditional), axis=1)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:149: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   origin_date = origin_date.dt.to_period(self.origin_grain).dt.to_timestamp(
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:153: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   development_date = development_date.dt.to_period(
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/base.py:184: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   o = pd.period_range(
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/base.py:188: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   d = pd.period_range(
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:331: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   return pd.DatetimeIndex(self.odims, name="origin").to_period(freq=freq)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 17
#       2 import pandas as pd
#       4 triangle = cl.Triangle(
#       5     df,
#       6     origin="accident_date",
#    (...)
#      13     cumulative=True
#      14 )
#      15 dev = cl.TweedieGLM(
#      16     design_matrix="C(line_of_business) + C(development) + C(origin)", link="log", power=1
# ---> 17 ).fit(triangle)
#      19 # Grab LDFs vs traditional approach
#      20 glm = dev.ldf_.iloc[..., 0, :].T.iloc[:, 0].rename("GLM")
#
# File ~/.local/lib/python3.10/site-packages/chainladder/development/glm.py:102, in TweedieGLM.fit(self, X, y, sample_weight)
#      94 def fit(self, X, y=None, sample_weight=None):
#      95     response = X.columns[0] if not self.response else self.response
#      96     self.model_ = DevelopmentML(Pipeline(steps=[
#      97         ('design_matrix', PatsyFormula(self.design_matrix)),
#      98         ('model', TweedieRegressor(
#      99                 link=self.link, power=self.power, max_iter=self.max_iter,
#     100                 tol=self.tol, warm_start=self.warm_start,
#     101                 verbose=self.verbose, fit_intercept=False))]),
# --> 102                 y_ml=response, weight_ml=self.weight).fit(X)
#     103     return self
#
# File ~/.local/lib/python3.10/site-packages/chainladder/development/learning.py:182, in DevelopmentML.fit(self, X, y, sample_weight)
#     180 self.df_ = df
#     181 # Fit model
# --> 182 self.estimator_ml.fit(df, self.y_ml_.fit_transform(df).squeeze())
#     183 #return self
#     184 self.triangle_ml_ = self._get_triangle_ml(df)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:471, in Pipeline.fit(self, X, y, **params)
#     428 """Fit the model.
#     429
#     430 Fit all the transformers one after the other and sequentially transform the
#    (...)
#     468     Pipeline with fitted steps.
#     469 """
#     470 routed_params = self._check_method_params(method="fit", props=params)
# --> 471 Xt = self._fit(X, y, routed_params)
#     472 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     473     if self._final_estimator != "passthrough":
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:408, in Pipeline._fit(self, X, y, routed_params)
#     406     cloned_transformer = clone(transformer)
#     407 # Fit or load from cache the current transformer
# --> 408 X, fitted_transformer = fit_transform_one_cached(
#     409     cloned_transformer,
#     410     X,
#     411     y,
#     412     None,
#     413     message_clsname="Pipeline",
#     414     message=self._log_message(step_idx),
#     415     params=routed_params[name],
#     416 )
#     417 # Replace the transformer of the step with the fitted
#     418 # transformer. This is necessary when loading the transformer
#     419 # from the cache.
#     420 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/.local/lib/python3.10/site-packages/joblib/memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:1303, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1301 with _print_elapsed_time(message_clsname, message):
#    1302     if hasattr(transformer, "fit_transform"):
# -> 1303         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1304     else:
#    1305         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1306             X, **params.get("transform", {})
#    1307         )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1101, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
# -> 1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/lib/python3.10/site-packages/chainladder/utils/utility_functions.py:337, in PatsyFormula.fit(self, X, y, sample_weight)
#     335 def fit(self, X, y=None, sample_weight=None):
#     336     self._check_X(X)
# --> 337     self.design_info_ = dmatrix(self.formula, X).design_info
#     338     return self
#
# File ~/.local/lib/python3.10/site-packages/patsy/highlevel.py:290, in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     227 """Construct a single design matrix given a formula_like and data.
#     228
#     229 :arg formula_like: An object that can be used to construct a design
#    (...)
#     287    The ``NA_action`` argument.
#     288 """
#     289 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 290 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     291                                   NA_action, return_type)
#     292 if lhs.shape[1] != 0:
#     293     raise PatsyError("encountered outcome variables for a model "
#     294                         "that does not expect them")
#
# File ~/.local/lib/python3.10/site-packages/patsy/highlevel.py:164, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162 def data_iter_maker():
#     163     return iter([data])
# --> 164 design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                   NA_action)
#     166 if design_infos is not None:
#     167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#
# File ~/.local/lib/python3.10/site-packages/patsy/highlevel.py:66, in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64 if isinstance(formula_like, ModelDesc):
#      65     assert isinstance(eval_env, EvalEnvironment)
# ---> 66     return design_matrix_builders([formula_like.lhs_termlist,
#      67                                    formula_like.rhs_termlist],
#      68                                   data_iter_maker,
#      69                                   eval_env,
#      70                                   NA_action)
#      71 else:
#      72     return None
#
# File ~/.local/lib/python3.10/site-packages/patsy/build.py:719, in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     717 design_infos = []
#     718 for termlist in termlists:
# --> 719     term_to_subterm_infos = _make_subterm_infos(termlist,
#     720                                                 num_column_counts,
#     721                                                 cat_levels_contrasts)
#     722     assert isinstance(term_to_subterm_infos, OrderedDict)
#     723     assert frozenset(term_to_subterm_infos) == frozenset(termlist)
#
# File ~/.local/lib/python3.10/site-packages/patsy/build.py:626, in _make_subterm_infos(terms, num_column_counts, cat_levels_contrasts)
#     623 levels, contrast = cat_levels_contrasts[factor]
#     624 # This is where the default coding is set to
#     625 # Treatment:
# --> 626 coded = code_contrast_matrix(factor_coding[factor],
#     627                              levels, contrast,
#     628                              default=Treatment)
#     629 contrast_matrices[factor] = coded
#     630 subterm_columns *= coded.matrix.shape[1]
#
# File ~/.local/lib/python3.10/site-packages/patsy/contrasts.py:602, in code_contrast_matrix(intercept, levels, contrast, default)
#     600     return contrast.code_with_intercept(levels)
#     601 else:
# --> 602     return contrast.code_without_intercept(levels)
#
# File ~/.local/lib/python3.10/site-packages/patsy/contrasts.py:183, in Treatment.code_without_intercept(self, levels)
#     181 else:
#     182     reference = _get_level(levels, self.reference)
# --> 183 eye = np.eye(len(levels) - 1)
#     184 contrasts = np.vstack((eye[:reference, :],
#     185                         np.zeros((1, len(levels) - 1)),
#     186                         eye[reference:, :]))
#     187 names = _name_levels("T.", levels[:reference] + levels[reference + 1:])
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/twodim_base.py:211, in eye(N, M, k, dtype, order, like)
#     209 if M is None:
#     210     M = N
# --> 211 m = zeros((N, M), dtype=dtype, order=order)
#     212 if k >= M:
#     213     return m
#
# ValueError: negative dimensions are not allowed

# %%
X
# Out:
#      Intercept  C(line_of_business)[T.Medical expense insurance]  \
# 0          1.0                                                 1
# 1          1.0                                                 1
# 2          1.0                                                 1
# 3          1.0                                                 1
# 4          1.0                                                 1
# ..         ...                                               ...
# 215        1.0                                                 0
# 216        1.0                                                 0
# 217        1.0                                                 0
# 218        1.0                                                 0
# 219        1.0                                                 0
#
#      C(line_of_business)[T.Motor vehicle liability insurance]  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 215                                                  1
# 216                                                  1
# 217                                                  1
# 218                                                  1
# 219                                                  1
#
#      C(line_of_business)[T.Workers' compensation insurance]  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 215                                                  0
# 216                                                  0
# 217                                                  0
# 218                                                  0
# 219                                                  0
#
#      C(development_date)[T.1989-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1990-02-20 00:00:00]  \
# 0                                             1
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1991-02-20 00:00:00]  \
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1992-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             1
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1993-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             1
# 4                                             0
# ..                                          ...
# 215                                           1
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1994-02-20 00:00:00]  ...  \
# 0                                             0  ...
# 1                                             0  ...
# 2                                             0  ...
# 3                                             0  ...
# 4                                             1  ...
# ..                                          ...  ...
# 215                                           0  ...
# 216                                           1  ...
# 217                                           0  ...
# 218                                           0  ...
# 219                                           0  ...
#
#      C(development_date)[T.1997-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           1
#
#      C(accident_date)[T.1989-02-20 00:00:00]  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 215                                        1
# 216                                        1
# 217                                        1
# 218                                        1
# 219                                        1
#
#      C(accident_date)[T.1990-02-20 00:00:00]  \
# 0                                          1
# 1                                          1
# 2                                          1
# 3                                          1
# 4                                          1
# ..                                       ...
# 215                                        0
# 216                                        0
# 217                                        0
# 218                                        0
# 219                                        0
#
#      C(accident_date)[T.1991-02-20 00:00:00]  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 215                                        0
# 216                                        0
# 217                                        0
# 218                                        0
# 219                                        0
#
#      C(accident_date)[T.1992-02-20 00:00:00]  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 215                                        0
# 216                                        0
# 217                                        0
# 218                                        0
# 219                                        0
#
#      C(accident_date)[T.1993-02-20 00:00:00]  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 215                                        0
# 216                                        0
# 217                                        0
# 218                                        0
# 219                                        0
#
#      C(accident_date)[T.1994-02-20 00:00:00]  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 215                                        0
# 216                                        0
# 217                                        0
# 218                                        0
# 219                                        0
#
#      C(accident_date)[T.1995-02-20 00:00:00]  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 215                                        0
# 216                                        0
# 217                                        0
# 218                                        0
# 219                                        0
#
#      C(accident_date)[T.1996-02-20 00:00:00]  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 215                                        0
# 216                                        0
# 217                                        0
# 218                                        0
# 219                                        0
#
#      C(accident_date)[T.1997-02-20 00:00:00]
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 215                                        0
# 216                                        0
# 217                                        0
# 218                                        0
# 219                                        0
#
# [220 rows x 22 columns]

# %%
X
# Out:
#      incremental_incurred_claims_usd
# 0                           421814.0
# 1                            -6641.0
# 2                           -24473.0
# 3                           -38948.0
# 4                           -24250.0
# ..                               ...
# 215                         -48499.0
# 216                         -45926.0
# 217                         -56449.0
# 218                         -12845.0
# 219                          -6453.0
#
# [220 rows x 1 columns]

# %%
triangle.to_frame(keepdims=True, implicit_axis=True).valuation.unique()
# Out:
# <DatetimeArray>
# ['1987-12-31 23:59:59.999999999', '1988-12-31 23:59:59.999999999',
#  '1989-12-31 23:59:59.999999999', '1990-12-31 23:59:59.999999999',
#  '1991-12-31 23:59:59.999999999', '1992-12-31 23:59:59.999999999',
#  '1993-12-31 23:59:59.999999999', '1994-12-31 23:59:59.999999999',
#  '1995-12-31 23:59:59.999999999', '1996-12-31 23:59:59.999999999',
#  '1988-11-30 23:59:59.999999999', '1989-11-30 23:59:59.999999999',
#  '1990-11-30 23:59:59.999999999', '1992-11-30 23:59:59.999999999',
#  '1993-11-30 23:59:59.999999999', '1994-11-30 23:59:59.999999999',
#  '1996-11-30 23:59:59.999999999']
# Length: 17, dtype: datetime64[ns]

# %%
df.development_date.unique()
# Out:
# <DatetimeArray>
# ['1990-02-20 00:00:00', '1991-02-20 00:00:00', '1992-02-20 00:00:00',
#  '1993-02-20 00:00:00', '1994-02-20 00:00:00', '1995-02-20 00:00:00',
#  '1996-02-20 00:00:00', '1997-02-20 00:00:00', '1989-02-20 00:00:00',
#  '1988-02-20 00:00:00']
# Length: 10, dtype: datetime64[us]

# %%
tri_test
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:331: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   return pd.DatetimeIndex(self.odims, name="origin").to_period(freq=freq)
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:331: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   return pd.DatetimeIndex(self.odims, name="origin").to_period(freq=freq)
#              11          12          23          24          35          36          48          59          60          71          72          83          84          96          107         108         120
# 1987         NaN  11644995.0         NaN  11674240.0         NaN  11653597.0  11630882.0         NaN  11593868.0         NaN  11551625.0         NaN  11463312.0  11420238.0         NaN  11415560.0  11396981.0
# 1988  13123290.0         NaN  13118789.0         NaN  13113024.0         NaN  13050144.0  12959037.0         NaN  12866709.0         NaN  12787372.0         NaN  12757420.0  12743440.0         NaN         NaN
# 1989  14776079.0         NaN  14670690.0         NaN         NaN  14479699.0  14324680.0  14183178.0         NaN  14033498.0         NaN         NaN  13948139.0  13925679.0         NaN         NaN         NaN
# 1990  15318373.0         NaN         NaN  15112547.0         NaN  14877662.0  14615540.0  14380205.0         NaN         NaN  14205778.0         NaN  14154882.0         NaN         NaN         NaN         NaN
# 1991         NaN  16828857.0         NaN  16457307.0         NaN  15999385.0  15538214.0         NaN  15249286.0         NaN  15161066.0         NaN         NaN         NaN         NaN         NaN         NaN
# 1992  18169370.0         NaN  17590902.0         NaN  17080187.0         NaN  16485467.0  16281774.0         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 1993  19414898.0         NaN  18609089.0         NaN         NaN  17854178.0  17521037.0         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 1994  19502850.0         NaN         NaN  18668388.0         NaN  17901550.0         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 1995         NaN  19142090.0         NaN  17910743.0         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 1996  18113581.0         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 1997         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN

# %%
df.development_date.unique()
# Out:
# <DatetimeArray>
# ['1990-02-20 00:00:00', '1991-02-20 00:00:00', '1992-02-20 00:00:00',
#  '1993-02-20 00:00:00', '1994-02-20 00:00:00', '1995-02-20 00:00:00',
#  '1996-02-20 00:00:00', '1997-02-20 00:00:00', '1989-02-20 00:00:00',
#  '1988-02-20 00:00:00']
# Length: 10, dtype: datetime64[us]

# %%
X
# Out:
#      Intercept  C(development_date)[T.1989-02-20 00:00:00]  \
# 0          1.0                                           0
# 1          1.0                                           0
# 2          1.0                                           0
# 3          1.0                                           0
# 4          1.0                                           0
# ..         ...                                         ...
# 215        1.0                                           0
# 216        1.0                                           0
# 217        1.0                                           0
# 218        1.0                                           0
# 219        1.0                                           0
#
#      C(development_date)[T.1990-02-20 00:00:00]  \
# 0                                             1
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1991-02-20 00:00:00]  \
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1992-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             1
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1993-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             1
# 4                                             0
# ..                                          ...
# 215                                           1
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1994-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             1
# ..                                          ...
# 215                                           0
# 216                                           1
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1995-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           1
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1996-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           1
# 219                                           0
#
#      C(development_date)[T.1997-02-20 00:00:00]
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           1
#
# [220 rows x 10 columns]

# %%
X
# Out:
#      Intercept  C(line_of_business)[T.Medical expense insurance]  \
# 0          1.0                                                 1
# 1          1.0                                                 1
# 2          1.0                                                 1
# 3          1.0                                                 1
# 4          1.0                                                 1
# ..         ...                                               ...
# 215        1.0                                                 0
# 216        1.0                                                 0
# 217        1.0                                                 0
# 218        1.0                                                 0
# 219        1.0                                                 0
#
#      C(line_of_business)[T.Motor vehicle liability insurance]  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 215                                                  1
# 216                                                  1
# 217                                                  1
# 218                                                  1
# 219                                                  1
#
#      C(line_of_business)[T.Workers' compensation insurance]  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 215                                                  0
# 216                                                  0
# 217                                                  0
# 218                                                  0
# 219                                                  0
#
#      C(development_date)[T.1989-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1990-02-20 00:00:00]  \
# 0                                             1
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1991-02-20 00:00:00]  \
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1992-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             1
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1993-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             1
# 4                                             0
# ..                                          ...
# 215                                           1
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1994-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             1
# ..                                          ...
# 215                                           0
# 216                                           1
# 217                                           0
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1995-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           1
# 218                                           0
# 219                                           0
#
#      C(development_date)[T.1996-02-20 00:00:00]  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           1
# 219                                           0
#
#      C(development_date)[T.1997-02-20 00:00:00]
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 215                                           0
# 216                                           0
# 217                                           0
# 218                                           0
# 219                                           1
#
# [220 rows x 13 columns]

# %%
glm = GeneralizedLinearRegressor(family='poisson', link='log')
glm.fit(X, y.values)

# After fitting, you can predict with the model and/or evaluate its performance
# predictions = glm.predict(X.design_matrix)

# Print model coefficients, intercept, or use other model attributes/methods as needed
print("Coefficients:", np.exp(glm.coef_))
print("Intercept:", glm.intercept_)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   line_of_business_id              220 non-null    int32
#  1   line_of_business                 220 non-null    object
#  2   accident_date                    220 non-null    datetime64[us]
#  3   development_date                 220 non-null    datetime64[us]
#  4   accident_year                    220 non-null    int32
#  5   development_year                 220 non-null    int32
#  6   development_lag                  220 non-null    int64
#  7   incurred_claims_usd              220 non-null    float64
#  8   paid_claims_usd                  220 non-null    float64
#  9   reserved_claims_usd              220 non-null    float64
#  10  earned_premium_usd               220 non-null    float64
#  11  incremental_incurred_claims_usd  220 non-null    float64
#  12  incremental_paid_claims_usd      220 non-null    float64
#  13  incremental_reserved_claims_usd  220 non-null    float64
# dtypes: datetime64[us](2), float64(7), int32(3), int64(1), object(1)
# memory usage: 21.6+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd

def calculate_chain_ladder_factors(df, development='development_lag', origin ='accident_date', amount='incurred_claims_usd'):
    # Group data by development period
    grouped = df.groupby(["line_of_business", development])

    # Calculate simple average factors
    simple_factors = grouped[amount].pct_change() + 1  

    # Calculate volume-weighted factors
    def weighted_factor(group):
        group['volume'] = group[amount].shift(1)
        return ((group[amount] * group['volume']).sum() / group['volume'].sum())

    volume_weighted_factors = grouped.apply(weighted_factor)

    return simple_factors, volume_weighted_factors

# Example usage (assuming you have your data loaded in 'df')
simple_factors, volume_weighted_factors = calculate_chain_ladder_factors(df) 
print("simple factors:", simple_factors.head())
print(volume_weighted_factors)
# Out:
# simple factors: 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: incurred_claims_usd, dtype: float64
# line_of_business                   development_lag
# General liability insurance        0                  7.205721e+05
#                                    1                  7.466600e+05
#                                    2                  7.188816e+05
#                                    3                  6.691707e+05
#                                    4                  6.087223e+05
#                                    5                  5.739989e+05
#                                    6                  5.579097e+05
#                                    7                  5.233254e+05
#                                    8                  4.994040e+05
#                                    9                           NaN
# Medical expense insurance          0                  4.881687e+05
#                                    1                  4.609513e+05
#                                    2                  4.251507e+05
#                                    3                  3.916804e+05
#                                    4                  3.533594e+05
#                                    5                  3.137209e+05
#                                    6                  2.857214e+05
#                                    7                  2.480902e+05
#                                    8                  2.410220e+05
#                                    9                           NaN
# Motor vehicle liability insurance  0                  1.355589e+07
#                                    1                  1.293331e+07
#                                    2                  1.234667e+07
#                                    3                  1.179313e+07
#                                    4                  1.122892e+07
#                                    5                  1.102004e+07
#                                    6                  1.042171e+07
#                                    7                  1.098620e+07
#                                    8                  1.054075e+07
#                                    9                           NaN
# Workers' compensation insurance    0                  1.591028e+06
#                                    1                  1.636816e+06
#                                    2                  1.603124e+06
#                                    3                  1.561863e+06
#                                    4                  1.551863e+06
#                                    5                  1.549030e+06
#                                    6                  1.526162e+06
#                                    7                  1.464506e+06
#                                    8                  1.362009e+06
#                                    9                           NaN
# dtype: float64
# /tmp/ipykernel_18613/336010136.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   return ((group[amount] * group['volume']).sum() / group['volume'].sum())
# /tmp/ipykernel_18613/336010136.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   return ((group[amount] * group['volume']).sum() / group['volume'].sum())
# /tmp/ipykernel_18613/336010136.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   return ((group[amount] * group['volume']).sum() / group['volume'].sum())
# /tmp/ipykernel_18613/336010136.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   return ((group[amount] * group['volume']).sum() / group['volume'].sum())
# /tmp/ipykernel_18613/336010136.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   volume_weighted_factors = grouped.apply(weighted_factor)

# %%
import polars as pl

def calculate_chain_ladder_factors(df, development='development_lag', origin='accident_date', amount='incurred_claims_usd'):  
    def simple_factors_calc(df: pl.DataFrame) -> pl.Series:
        return df[amount].pct_change().fill_null(0) + 1

    def volume_weighted_factors_calc(df: pl.DataFrame) -> pl.Series:
        df = df.with_column(pl.col(amount).shift().alias("volume"))
        return (df[amount] * df["volume"]).sum() / df["volume"].sum()

    result = (df.group_by(development).agg(
        pl.map_groups(pl.col(*), simple_factors_calc).alias("simple_factors"),
        pl.map_groups(volume_weighted_factors_calc).alias("volume_weighted_factors")
    ))

    return result 
df_cl = calculate_chain_ladder_factors(pl.DataFrame(df)) 
print(df_cl)
# Out:
#   Cell In[16], line 12
#     pl.map_groups(pl.col(*), simple_factors_calc).alias("simple_factors"),
#                           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# Sample data
data = {'AY': ['2018', '2018', '2018', '2018', '2019', '2019', '2019', '2020', '2020'],
        'DevelopmentYear': [1, 2, 3, 4, 1, 2, 3, 1, 2],
        'CumulativeClaims': [100, 200, 250, 270, 120, 220, 260, 150, 230],
        'ClaimsVolume': [50, 45, 40, 35, 55, 50, 45, 60, 55]}  # ClaimsVolume for volume-weighted calculation

df = pd.DataFrame(data)

# Calculate Simple Chain-Ladder Factors
df['NextCumulativeClaims'] = df.groupby('AY')['CumulativeClaims'].shift(-1)
df['SimpleCLFactor'] = df['NextCumulativeClaims'] / df['CumulativeClaims']
simple_cl_factors = df.dropna(subset=['SimpleCLFactor'])[['AY', 'DevelopmentYear', 'SimpleCLFactor']]

print(simple_cl_factors)
# Out:
#      AY  DevelopmentYear  SimpleCLFactor
# 0  2018                1        2.000000
# 1  2018                2        1.250000
# 2  2018                3        1.080000
# 4  2019                1        1.833333
# 5  2019                2        1.181818
# 7  2020                1        1.533333

# %%
from glum import GeneralizedLinearRegressor
from formulaic import model_matrix
import numpy as np

y,X= model_matrix('log(incurred_claims_usd)~ C(line_of_business):C(development_date)', df)

glm = GeneralizedLinearRegressor(family='poisson', link='log')
glm.fit(X, y)

# After fitting, you can predict with the model and/or evaluate its performance
# predictions = glm.predict(X.design_matrix)

# Print model coefficients, intercept, or use other model attributes/methods as needed
print("Coefficients:", np.exp(glm.coef_))
print("Intercept:", glm.intercept_)
# Out:
# Coefficients: [1.         0.99806346 0.99883872 1.00000838 1.00066193 1.0010448
#  1.00109112 1.00094199 1.00075485 1.0004479  0.99471466 1.00850333
#  0.99986524 0.98969702 1.01684059 1.0005165  0.98569909 1.02452809
#  1.00110745 0.98215462 1.03131532 1.00195428 0.97898696 1.03777863
#  1.00271436 0.97545299 1.04387387 1.00354005 0.9724235  1.04964986
#  1.00402275 0.96998121 1.05491137 1.00433685 0.96792666 1.05964424
#  1.00431134 0.96555895 1.06391838 1.00423739]
# Intercept: 2.645369747496562
# /home/vscode/.local/lib/python3.10/site-packages/formulaic/transforms/contrasts.py:155: DataMismatchWarning: Data has categories outside of the nominated levels (or that were not seen in original dataset): {numpy.datetime64('1990-02-20T00:00:00.000000'), numpy.datetime64('1991-02-20T00:00:00.000000'), numpy.datetime64('1993-02-20T00:00:00.000000'), numpy.datetime64('1992-02-20T00:00:00.000000'), numpy.datetime64('1994-02-20T00:00:00.000000'), numpy.datetime64('1995-02-20T00:00:00.000000'), numpy.datetime64('1996-02-20T00:00:00.000000'), numpy.datetime64('1997-02-20T00:00:00.000000'), numpy.datetime64('1989-02-20T00:00:00.000000'), numpy.datetime64('1988-02-20T00:00:00.000000')}. They are being  cast to nan, which will likely skew the results of your analyses.
#   warnings.warn(
# /home/vscode/.local/lib/python3.10/site-packages/glum/_glm.py:2776: FutureWarning: The default value of `alpha` will become `0` in 3.0.0.
#   warnings.warn(
# /home/vscode/.local/lib/python3.10/site-packages/glum/_glm.py:146: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Working Chainladder
# Both simple and volume, but ugly

# %%
cl_test.groupby(["line_of_business","development_lag"])[["incurred_claims_usd","NextAmount"]].sum().assign(VolumeCL = lambda x: x["NextAmount"] / x["incurred_claims_usd"])
# Out:
#                                            incurred_claims_usd  NextAmount  \
# line_of_business          development_lag
# Medical expense insurance 0                          4313855.0   4150080.0
#                           1                          3606561.0   3413314.0
#                           2                          2887737.0   2692739.0
#                           3                          2225398.0   2099337.0
#                           4                          1689871.0   1570471.0
#                           5                          1208966.0   1153294.0
#                           6                           822851.0    775924.0
#                           7                           495513.0    486868.0
#                           8                           241022.0    236376.0
#
#                                            VolumeCL
# line_of_business          development_lag
# Medical expense insurance 0                0.962035
#                           1                0.946418
#                           2                0.932474
#                           3                0.943354
#                           4                0.929344
#                           5                0.953951
#                           6                0.942970
#                           7                0.982553
#                           8                0.980724

# %% [markdown]
# ## Polars version

# %%
def calculate_cl_factors(development: pl.Expr, origin=pl.Expr, amount=pl.Expr) -> pl.Expr:
    # Calculate  Chain-Ladder Factors, simple and volume-weighted with Polars
    cl_factor = (pl.col("incurred_claims_usd").pct_change().sort_by("line_of_business","accident_date","development_lag").over(["line_of_business","accident_date"]).fill_null(0)) +1)
    df['NextAmount'] = df.groupby([index, origin])[amount].shift(-1)
    df['SimpleCLFactor'] = df['NextAmount'] / df[amount]
Following is

# %%
sort_cols = index + origin + development
sort_cols
# Out:
# ['line_of_business', 'accident_date', 'development_date']

# %%
index = ["line_of_business"]
origin = ["accident_date"]
development = ["development_lag"]
amounts = ["incurred_claims_usd", "paid_claims_usd"]
# list concatinated, not list in list
sort_cols = [index, origin, development]
over_cols = [index, origin]

df_pl = pl.DataFrame(df)
df_pl_cl = (
    df_pl.select(index + origin + development + amounts)
    .sort(index + origin + development)
    .with_columns(
        lead_amount=pl.col(amounts[0]).shift(1).over(index + origin),
        cl_factor=(pl.col(amounts[0]).pct_change().over(index + origin).fill_null(0))
        + 1,
    )
    #.filter(pl.col("line_of_business") == "Medical expense insurance")
    
)
#Volum weighted average of cl_factor for line_of_business and development_date
cl_vol = df_pl_cl.group_by(index + development).agg(pl.col("cl_factor").mean().alias("cl_factor_simple"),
                                                    pl.col("cl_factor"),
                                                    pl.col("lead_amount"),
                                                    pl.col(amounts[0]),
)#.with_columns(volume_cl=pl.col("lead_amount") / pl.col(amounts[0]))

# %%
cl_vol.filter(pl.col("line_of_business") == "Medical expense insurance")
# Out:
# shape: (10, 6)
# ┌────────────────┬────────────────┬────────────────┬───────────────┬───────────────┬───────────────┐
# │ line_of_busine ┆ development_la ┆ cl_factor_simp ┆ cl_factor     ┆ lead_amount   ┆ incurred_clai │
# │ ss             ┆ g              ┆ le             ┆ ---           ┆ ---           ┆ ms_usd        │
# │ ---            ┆ ---            ┆ ---            ┆ list[f64]     ┆ list[f64]     ┆ ---           │
# │ str            ┆ i64            ┆ f64            ┆               ┆               ┆ list[f64]     │
# ╞════════════════╪════════════════╪════════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ Medical        ┆ 0              ┆ 1.0            ┆ [1.0, 1.0, …  ┆ [null, null,  ┆ [380154.0,    │
# │ expense        ┆                ┆                ┆ 1.0]          ┆ … null]       ┆ 363266.0, …   │
# │ insurance      ┆                ┆                ┆               ┆               ┆ 536705.0]     │
# │ Medical        ┆ 1              ┆ 0.961841       ┆ [0.907879,    ┆ [380154.0,    ┆ [345134.0,    │
# │ expense        ┆                ┆                ┆ 1.002918, …   ┆ 363266.0, …   ┆ 364326.0, …   │
# │ insurance      ┆                ┆                ┆ 0.97014]      ┆ 560248.0]     ┆ 543519.0]     │
# │ Medical        ┆ 2              ┆ 0.946369       ┆ [0.936515,    ┆ [345134.0,    ┆ [323223.0,    │
# │ expense        ┆                ┆                ┆ 0.968424, …   ┆ 364326.0, …   ┆ 352822.0, …   │
# │ insurance      ┆                ┆                ┆ 0.947112]     ┆ 554926.0]     ┆ 525577.0]     │
# │ Medical        ┆ 3              ┆ 0.933092       ┆ [0.954706,    ┆ [323223.0,    ┆ [308583.0,    │
# │ expense        ┆                ┆                ┆ 0.930373, …   ┆ 352822.0, …   ┆ 328256.0, …   │
# │ insurance      ┆                ┆                ┆ 0.920713]     ┆ 507586.0]     ┆ 467341.0]     │
# │ Medical        ┆ 7              ┆ 0.942734       ┆ [0.924816,    ┆ [260387.0,    ┆ [240810.0,    │
# │ expense        ┆                ┆                ┆ 0.957566,     ┆ 265990.0,     ┆ 254703.0,     │
# │ insurance      ┆                ┆                ┆ 0.94582]      ┆ 296474.0]     ┆ 280411.0]     │
# │ Medical        ┆ 4              ┆ 0.942636       ┆ [0.963196,    ┆ [308583.0,    ┆ [297226.0,    │
# │ expense        ┆                ┆                ┆ 0.907137, …   ┆ 328256.0, …   ┆ 297773.0, …   │
# │ insurance      ┆                ┆                ┆ 0.955923]     ┆ 428346.0]     ┆ 409466.0]     │
# │ Medical        ┆ 5              ┆ 0.929832       ┆ [0.919122,    ┆ [297226.0,    ┆ [273187.0,    │
# │ expense        ┆                ┆                ┆ 0.937318, …   ┆ 297773.0, …   ┆ 279108.0, …   │
# │ insurance      ┆                ┆                ┆ 0.914686]     ┆ 395223.0]     ┆ 361505.0]     │
# │ Medical        ┆ 6              ┆ 0.953941       ┆ [0.953146,    ┆ [273187.0,    ┆ [260387.0,    │
# │ expense        ┆                ┆                ┆ 0.953, …      ┆ 279108.0, …   ┆ 265990.0, …   │
# │ insurance      ┆                ┆                ┆ 0.952689]     ┆ 346853.0]     ┆ 330443.0]     │
# │ Medical        ┆ 8              ┆ 0.983053       ┆ [1.00088,     ┆ [240810.0,    ┆ [241022.0,    │
# │ expense        ┆                ┆                ┆ 0.965226]     ┆ 254703.0]     ┆ 245846.0]     │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 9              ┆ 0.980724       ┆ [0.980724]    ┆ [241022.0]    ┆ [236376.0]    │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# └────────────────┴────────────────┴────────────────┴───────────────┴───────────────┴───────────────┘

# %%
df.sample(10)
# Out:
#      line_of_business_id                   line_of_business accident_date  \
# 66                     8        General liability insurance    1988-02-20
# 49                     4  Motor vehicle liability insurance    1991-02-20
# 201                    8        General liability insurance    1990-02-20
# 198                    8        General liability insurance    1990-02-20
# 134                    8        General liability insurance    1993-02-20
# 3                      1          Medical expense insurance    1990-02-20
# 43                     4  Motor vehicle liability insurance    1991-02-20
# 110                    8        General liability insurance    1995-02-20
# 6                      1          Medical expense insurance    1990-02-20
# 58                     1          Medical expense insurance    1991-02-20
#
#     development_date  accident_year  development_year  development_lag  \
# 66        1988-02-20           1988              1988                0
# 49        1997-02-20           1991              1997                6
# 201       1993-02-20           1990              1993                3
# 198       1990-02-20           1990              1990                0
# 134       1995-02-20           1993              1995                2
# 3         1993-02-20           1990              1993                3
# 43        1991-02-20           1991              1991                0
# 110       1996-02-20           1995              1996                1
# 6         1996-02-20           1990              1996                6
# 58        1994-02-20           1991              1994                3
#
#      incurred_claims_usd  paid_claims_usd  reserved_claims_usd  \
# 66              448957.0          39166.0             409791.0
# 49            11561602.0       11425383.0             136219.0
# 201             598058.0         334211.0             263847.0
# 198             593294.0          49382.0             543912.0
# 134             775163.0         341873.0             433290.0
# 3               351752.0         163695.0             188057.0
# 43            12561606.0        4245091.0            8316515.0
# 110             844633.0         212724.0             631909.0
# 6               296474.0         225199.0              71275.0
# 58              391085.0         199262.0             191823.0
#
#      earned_premium_usd  incremental_incurred_claims_usd  \
# 66             972971.0                         448957.0
# 49           15781531.0                         -47329.0
# 201           1044412.0                          -4382.0
# 198           1044412.0                         593294.0
# 134           1206095.0                         -34235.0
# 3              460119.0                         -38948.0
# 43           15781531.0                       12561606.0
# 110           1482542.0                         -62440.0
# 6              460119.0                         -13344.0
# 58             436063.0                         -21518.0
#
#      incremental_paid_claims_usd  incremental_reserved_claims_usd
# 66                       39166.0                         409791.0
# 49                      114965.0                        -162294.0
# 201                     107050.0                        -111432.0
# 198                      49382.0                         543912.0
# 134                     142651.0                        -176886.0
# 3                        44731.0                         -83679.0
# 43                     4245091.0                        8316515.0
# 110                     162680.0                        -225120.0
# 6                        11227.0                         -24571.0
# 58                       52915.0                         -74433.0

# %%
index = ["line_of_business"]
origin = ["accident_date"]
development = ["development_lag"]
amounts = ["incurred_claims_usd", "paid_claims_usd"]
def calculate_simple_chain_ladder_factors(df, development='development_lag', origin='accident_date', amount='incurred_claims_usd', index='line_of_business'):
    df['NextAmount'] = df.groupby([index, origin])[amount].shift(-1)
    df['SimpleCLFactor'] = df['NextAmount'] / df[amount]
    return df.dropna(subset=['SimpleCLFactor'])[[index, origin, development, amount,"NextAmount", 'SimpleCLFactor']]
cl_test = calculate_simple_chain_ladder_factors(df).query("line_of_business == 'Medical expense insurance'")
cl_test.reset_index().groupby(["line_of_business","development_lag"])["SimpleCLFactor"].mean()
# Out:
# /tmp/ipykernel_69096/4235522500.py:6: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   df['NextAmount'] = df.groupby([index, origin])[amount].shift(-1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[174], line 9
#       7     df['SimpleCLFactor'] = df['NextAmount'] / df[amount]
#       8     return df.dropna(subset=['SimpleCLFactor'])[[index, origin, development, amount,"NextAmount", 'SimpleCLFactor']]
# ----> 9 cl_test = calculate_simple_chain_ladder_factors(df).query("line_of_business == 'Medical expense insurance'")
#      10 cl_test.reset_index().groupby(["line_of_business","development_lag"])["SimpleCLFactor"].mean()
#
# Cell In[174], line 6, in calculate_simple_chain_ladder_factors(df, development, origin, amount, index)
#       5 def calculate_simple_chain_ladder_factors(df, development='development_lag', origin='accident_date', amount='incurred_claims_usd', index='line_of_business'):
# ----> 6     df['NextAmount'] = df.groupby([index, origin])[amount].shift(-1)
#       7     df['SimpleCLFactor'] = df['NextAmount'] / df[amount]
#       8     return df.dropna(subset=['SimpleCLFactor'])[[index, origin, development, amount,"NextAmount", 'SimpleCLFactor']]
#
# TypeError: 'GroupBy' object is not subscriptable

# %%
df
# Out:
# shape: (10, 5)
# ┌─────────────────────────────────┬─────────────────┬────────────────────┬──────────┬──────────────┐
# │ line_of_business                ┆ development_lag ┆ cl_factor_incurred ┆ dev_year ┆ cdf_incurred │
# │ ---                             ┆ ---             ┆ ---                ┆ ---      ┆ ---          │
# │ str                             ┆ i64             ┆ f64                ┆ i32      ┆ f64          │
# ╞═════════════════════════════════╪═════════════════╪════════════════════╪══════════╪══════════════╡
# │ Workers' compensation insurance ┆ 0               ┆ 1.0                ┆ 1997     ┆ 0.995955     │
# │ Workers' compensation insurance ┆ 1               ┆ 1.023213           ┆ 1997     ┆ 0.996527     │
# │ Workers' compensation insurance ┆ 7               ┆ 1.000317           ┆ 1997     ┆ 0.996843     │
# │ Workers' compensation insurance ┆ 9               ┆ 0.995955           ┆ 1997     ┆ 0.993867     │
# │ Workers' compensation insurance ┆ 2               ┆ 0.975516           ┆ 1997     ┆ 0.990414     │
# │ Workers' compensation insurance ┆ 3               ┆ 0.981517           ┆ 1997     ┆ 0.987033     │
# │ Workers' compensation insurance ┆ 4               ┆ 0.996586           ┆ 1997     ┆ 0.96879      │
# │ Workers' compensation insurance ┆ 5               ┆ 0.996526           ┆ 1997     ┆ 0.94507      │
# │ Workers' compensation insurance ┆ 6               ┆ 0.997014           ┆ 1997     ┆ 0.967007     │
# │ Workers' compensation insurance ┆ 8               ┆ 1.000575           ┆ 1997     ┆ 0.967007     │
# └─────────────────────────────────┴─────────────────┴────────────────────┴──────────┴──────────────┘

# %% [markdown]
# ## Numpy

# %%
index = ["line_of_business"]
origin = ["accident_date"]
development = ["development_lag"]
amounts = ["incurred_claims_usd", "paid_claims_usd"]

import numpy as np
def calculate_simple_ldf_factors(matrix):
    # Calculate the ratio of each element to its previous element in each row (AY)
    simple_factors = matrix[:, 1:] / matrix[:, :-1]
    # Calculate the average factor for each development lag across all AYs
    # Ignore NaN values by using np.nanmean
    avg_simple_factors = np.nanmean(simple_factors, axis=0)
    avg_simple_factors[np.isnan(avg_simple_factors)]=1.0
    return avg_simple_factors

def calculate_simple_cdf_factors(ldf):
    return np.cumprod(ldf[::-1])[::-1]


tri_pl = df.pivot(index=index+origin, columns=development, values="incurred_claims_usd", aggregate_function="sum")

# %%
tri_pl
# Out:
# shape: (40, 12)
# ┌────────────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬──────┐
# │ line_of_bu ┆ accident_d ┆ 0          ┆ 1          ┆ … ┆ 6         ┆ 7         ┆ 8         ┆ 9    │
# │ siness     ┆ ate        ┆ ---        ┆ ---        ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---  │
# │ ---        ┆ ---        ┆ f64        ┆ f64        ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64  │
# │ str        ┆ date       ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪══════╡
# │ Medical    ┆ 1989-02-20 ┆ 363266.0   ┆ 364326.0   ┆ … ┆ 265990.0  ┆ 254703.0  ┆ 245846.0  ┆ null │
# │ expense    ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insurance  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Workers'   ┆ 1990-02-20 ┆ 1.477245e6 ┆ 1.621324e6 ┆ … ┆ 1.568607e ┆ 1.573819e ┆ null      ┆ null │
# │ compensati ┆            ┆            ┆            ┆   ┆ 6         ┆ 6         ┆           ┆      │
# │ on         ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insurance  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Workers'   ┆ 1995-02-20 ┆ 1.750767e6 ┆ 1.692856e6 ┆ … ┆ null      ┆ null      ┆ null      ┆ null │
# │ compensati ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ on         ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insurance  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Medical    ┆ 1995-02-20 ┆ 562089.0   ┆ 554926.0   ┆ … ┆ null      ┆ null      ┆ null      ┆ null │
# │ expense    ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insurance  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ General    ┆ 1993-02-20 ┆ 805843.0   ┆ 809398.0   ┆ … ┆ null      ┆ null      ┆ null      ┆ null │
# │ liability  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insurance  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ …          ┆ …          ┆ …          ┆ …          ┆ … ┆ …         ┆ …         ┆ …         ┆ …    │
# │ Motor      ┆ 1995-02-20 ┆ 1.6282921e ┆ 1.5575973e ┆ … ┆ null      ┆ null      ┆ null      ┆ null │
# │ vehicle    ┆            ┆ 7          ┆ 7          ┆   ┆           ┆           ┆           ┆      │
# │ liability  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insuranc…  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ General    ┆ 1990-02-20 ┆ 593294.0   ┆ 614502.0   ┆ … ┆ 546687.0  ┆ 544668.0  ┆ null      ┆ null │
# │ liability  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insurance  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ General    ┆ 1989-02-20 ┆ 524433.0   ┆ 528356.0   ┆ … ┆ 503168.0  ┆ 499956.0  ┆ 499404.0  ┆ null │
# │ liability  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insurance  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Workers'   ┆ 1993-02-20 ┆ 1.719891e6 ┆ 1.714687e6 ┆ … ┆ null      ┆ null      ┆ null      ┆ null │
# │ compensati ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ on         ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insurance  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Motor      ┆ 1989-02-20 ┆ 1.0851891e ┆ 1.0784883e ┆ … ┆ 1.0560044 ┆ 1.0547199 ┆ 1.0540746 ┆ null │
# │ vehicle    ┆            ┆ 7          ┆ 7          ┆   ┆ e7        ┆ e7        ┆ e7        ┆      │
# │ liability  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ insuranc…  ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# └────────────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴──────┘

# %%
tri_pl_group = tri_pl.group_by("line_of_business")

development_lag = {}
ldf_groups = {}
cdf_groups = {}
for g,values  in tri_pl_group:
    single_triangle = values.sort(origin).select(pl.exclude(index + origin))
    development_lag[g] = single_triangle.columns
    ldf_groups[g] = calculate_simple_ldf_factors(single_triangle.to_numpy())
    cdf_groups[g] = calculate_simple_cdf_factors(ldf_groups[g])
# Out:
# /tmp/ipykernel_123763/463844275.py:6: DeprecationWarning: `group_by` iteration will change to always return group identifiers as tuples. Pass `by` as a list to silence this warning, e.g. `group_by(['line_of_business'])`.
#   for g,values  in tri_pl_group:

# %%
def calculated_cl_factors(df, amount=['incurred_claims_usd'], index= ["line_of_business"], development=['development_lag'], origin=['accident_date']):
    
    for i, amount in enumerate(amounts):
        triangles = df.pivot(index=index+origin, columns=development, values=amount, aggregate_function="sum")
        dataframes = []
        for g, values in triangles.group_by("line_of_business"):
            single_triangle = values.sort(origin).select(pl.exclude(index + origin))
            ldf = calculate_simple_ldf_factors(single_triangle.to_numpy())
            cdf = calculate_simple_cdf_factors(ldf)
            dataframes.append(
                pl.DataFrame(
                    {
                        "line_of_business": g,
                        "development_lag": [int(col) for col in single_triangle.columns[:-1]],
                        "ldf_"+amount: ldf,
                        "cdf_"+amount: cdf,
                    },
                    
                ).sort(["line_of_business","development_lag"])
            )
        if i==0:
            df_cl_factors = pl.concat(dataframes)
        else:
            df_cl_factors = df_cl_factors.join(pl.concat(dataframes), on = index + development)

    return df_cl_factors

# %%
test_dev = calculated_cl_factors(df)
# Out:
# /tmp/ipykernel_1056/2090189784.py:6: DeprecationWarning: `group_by` iteration will change to always return group identifiers as tuples. Pass `by` as a list to silence this warning, e.g. `group_by(['line_of_business'])`.
#   for g, values in triangles.group_by("line_of_business"):

# %%
test_dev
# Out:
# shape: (36, 6)
# ┌────────────────┬────────────────┬────────────────┬───────────────┬───────────────┬───────────────┐
# │ line_of_busine ┆ development_la ┆ ldf_incurred_c ┆ cdf_incurred_ ┆ ldf_paid_clai ┆ cdf_paid_clai │
# │ ss             ┆ g              ┆ laims_usd      ┆ claims_usd    ┆ ms_usd        ┆ ms_usd        │
# │ ---            ┆ ---            ┆ ---            ┆ ---           ┆ ---           ┆ ---           │
# │ str            ┆ i64            ┆ f64            ┆ f64           ┆ f64           ┆ f64           │
# ╞════════════════╪════════════════╪════════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ Medical        ┆ 0              ┆ 0.961841       ┆ 0.645463      ┆ 6.075951      ┆ 25.519739     │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 1              ┆ 0.946369       ┆ 0.67107       ┆ 1.97625       ┆ 4.200123      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 2              ┆ 0.933092       ┆ 0.7091        ┆ 1.383782      ┆ 2.125299      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 3              ┆ 0.942636       ┆ 0.759946      ┆ 1.199759      ┆ 1.535863      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 4              ┆ 0.929832       ┆ 0.806193      ┆ 1.101576      ┆ 1.280143      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ …              ┆ …              ┆ …              ┆ …             ┆ …             ┆ …             │
# │ Motor vehicle  ┆ 4              ┆ 0.993621       ┆ 0.986291      ┆ 1.021848      ┆ 1.042829      │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ Motor vehicle  ┆ 5              ┆ 0.994988       ┆ 0.992624      ┆ 1.010795      ┆ 1.020533      │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ Motor vehicle  ┆ 6              ┆ 0.99865        ┆ 0.997623      ┆ 1.005396      ┆ 1.009634      │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ Motor vehicle  ┆ 7              ┆ 0.999516       ┆ 0.998972      ┆ 1.002952      ┆ 1.004216      │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ Motor vehicle  ┆ 8              ┆ 0.999455       ┆ 0.999455      ┆ 1.00126       ┆ 1.00126       │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# └────────────────┴────────────────┴────────────────┴───────────────┴───────────────┴───────────────┘

# %%
"ldf_"+amounts[0]
# Out:
# 'ldf_incurred_claims_usd'

# %%
test_dev.head(2)
# Out:
# shape: (2, 5)
# ┌───────────────────────────────────┬─────────────────┬─────────────────────┬──────────┬──────────┐
# │ line_of_business                  ┆ development_lag ┆ amount_type         ┆ ldf      ┆ cdf      │
# │ ---                               ┆ ---             ┆ ---                 ┆ ---      ┆ ---      │
# │ str                               ┆ i64             ┆ str                 ┆ f64      ┆ f64      │
# ╞═══════════════════════════════════╪═════════════════╪═════════════════════╪══════════╪══════════╡
# │ Motor vehicle liability insuranc… ┆ 0               ┆ incurred_claims_usd ┆ 0.969737 ┆ 0.914558 │
# │ Motor vehicle liability insuranc… ┆ 1               ┆ incurred_claims_usd ┆ 0.979088 ┆ 0.9431   │
# └───────────────────────────────────┴─────────────────┴─────────────────────┴──────────┴──────────┘

# %%
amounts=["incurred_claims_usd","paid_claims_usd"]
df.groupby("line_of_business", "development_lag").agg()
# Out:
# shape: (36, 6)
# ┌────────────────┬────────────────┬────────────────┬───────────────┬───────────────┬───────────────┐
# │ line_of_busine ┆ development_la ┆ ldf_amount_typ ┆ ldf_amount_ty ┆ cdf_amount_ty ┆ cdf_amount_ty │
# │ ss             ┆ g              ┆ e_incurred_cla ┆ pe_paid_claim ┆ pe_incurred_c ┆ pe_paid_claim │
# │ ---            ┆ ---            ┆ ims_…          ┆ s_usd         ┆ laims_…       ┆ s_usd         │
# │ str            ┆ i64            ┆ ---            ┆ ---           ┆ ---           ┆ ---           │
# │                ┆                ┆ f64            ┆ f64           ┆ f64           ┆ f64           │
# ╞════════════════╪════════════════╪════════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ Motor vehicle  ┆ 0              ┆ 0.969737       ┆ 1.83119       ┆ 0.914558      ┆ 2.643895      │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ Motor vehicle  ┆ 1              ┆ 0.979088       ┆ 1.20972       ┆ 0.9431        ┆ 1.443813      │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ Motor vehicle  ┆ 2              ┆ 0.985854       ┆ 1.094253      ┆ 0.963243      ┆ 1.19351       │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ Motor vehicle  ┆ 3              ┆ 0.990645       ┆ 1.045912      ┆ 0.977064      ┆ 1.090707      │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ Motor vehicle  ┆ 4              ┆ 0.993621       ┆ 1.021848      ┆ 0.986291      ┆ 1.042829      │
# │ liability      ┆                ┆                ┆               ┆               ┆               │
# │ insuranc…      ┆                ┆                ┆               ┆               ┆               │
# │ …              ┆ …              ┆ …              ┆ …             ┆ …             ┆ …             │
# │ Medical        ┆ 4              ┆ 0.929832       ┆ 1.101576      ┆ 0.806193      ┆ 1.280143      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 5              ┆ 0.953941       ┆ 1.067977      ┆ 0.867031      ┆ 1.162102      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 6              ┆ 0.942734       ┆ 1.039102      ┆ 0.908893      ┆ 1.088134      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 7              ┆ 0.983053       ┆ 1.028556      ┆ 0.964104      ┆ 1.047187      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# │ Medical        ┆ 8              ┆ 0.980724       ┆ 1.018114      ┆ 0.980724      ┆ 1.018114      │
# │ expense        ┆                ┆                ┆               ┆               ┆               │
# │ insurance      ┆                ┆                ┆               ┆               ┆               │
# └────────────────┴────────────────┴────────────────┴───────────────┴───────────────┴───────────────┘

# %%
increments = np.diff(tri_np, axis=1)
weights = tri_np[:, :-1]
np.nanmean(increments / weights, axis=0) +1
# Out:
# array([0.96184102, 0.94636855, 0.9330923 , 0.94263576, 0.92983239,
#        0.95394109, 0.9427339 , 0.98305326, 0.98072375])

# %%
def calculate_volume_weighted_cl_factors_np(matrix):
    # Calculate the differences (increments) between development periods
    increments = np.diff(matrix, axis=1)
    
    # Calculate weights as the amounts themselves, shifted right to align with increments
    weights = matrix[:, :-1]  # Using amounts before each increment as weights
    
    # Volume-weighted calculation (simple average in this context, as weights align with amounts)
    weighted_averages = np.nanmean(increments / weights, axis=0)
    
    return weighted_averages

volume_weighted_cl_factors = calculate_volume_weighted_cl_factors_np(tri_pl.select(pl.exclude(index + origin)).to_numpy())
print("Volume-Weighted Chain-Ladder Factors:", volume_weighted_cl_factors+1)
# Out:
# Volume-Weighted Chain-Ladder Factors: [0.96184102 0.94636855 0.9330923  0.94263576 0.92983239 0.95394109
#  0.9427339  0.98305326 0.98072375]

# %%
simple = cl_vol.select(pl.col(index), pl.col(development),pl.col("cl_factor").list.mean()).sort(index + development)
simple
#cl_vol.select(np.average(pl.col("cl_factor"), weights=pl.col("incurred_claims_usd")))
# Out:
# shape: (40, 3)
# ┌─────────────────────────────────┬─────────────────┬───────────┐
# │ line_of_business                ┆ development_lag ┆ cl_factor │
# │ ---                             ┆ ---             ┆ ---       │
# │ str                             ┆ i64             ┆ f64       │
# ╞═════════════════════════════════╪═════════════════╪═══════════╡
# │ General liability insurance     ┆ 0               ┆ 1.0       │
# │ General liability insurance     ┆ 1               ┆ 0.985213  │
# │ General liability insurance     ┆ 2               ┆ 1.00355   │
# │ General liability insurance     ┆ 3               ┆ 0.967666  │
# │ General liability insurance     ┆ 4               ┆ 0.961066  │
# │ …                               ┆ …               ┆ …         │
# │ Workers' compensation insurance ┆ 5               ┆ 0.996526  │
# │ Workers' compensation insurance ┆ 6               ┆ 0.997014  │
# │ Workers' compensation insurance ┆ 7               ┆ 1.000317  │
# │ Workers' compensation insurance ┆ 8               ┆ 1.000575  │
# │ Workers' compensation insurance ┆ 9               ┆ 0.995955  │
# └─────────────────────────────────┴─────────────────┴───────────┘

# %%
tri_test= cl.Triangle(df, origin="accident_date", development="development_date", columns = "incurred_claims_usd", index="line_of_business", grain="OYDY", cumulative=True)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:149: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   origin_date = origin_date.dt.to_period(self.origin_grain).dt.to_timestamp(
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:153: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   development_date = development_date.dt.to_period(
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/base.py:184: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   o = pd.period_range(
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/base.py:188: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   d = pd.period_range(

# %%
cl.Development(average="volume").fit(tri_test).ldf_.loc["Medical expense insurance"]
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:331: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   return pd.DatetimeIndex(self.odims, name="origin").to_period(freq=freq)
#        11-23  12-24  23-35  24-36  35-47     36-48     48-60  59-71  60-72  71-83  72-84  83-95     84-96    96-108  107-119   108-120
# (All)    NaN    NaN    NaN    NaN    NaN  0.931316  0.938276    NaN    NaN    NaN    NaN    NaN  0.935998  0.965226      NaN  0.980724

# %%
tri_test.loc["Medical expense insurance"]
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:331: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   return pd.DatetimeIndex(self.odims, name="origin").to_period(freq=freq)
# /home/vscode/.local/lib/python3.10/site-packages/chainladder/core/triangle.py:331: FutureWarning: 'A-FEB' is deprecated and will be removed in a future version, please use 'Y-FEB' instead.
#   return pd.DatetimeIndex(self.odims, name="origin").to_period(freq=freq)
#            11        12        23        24        35        36        48        59        60        71        72        83        84        96        107       108       120
# 1987       NaN  380154.0       NaN  345134.0       NaN  323223.0  308583.0       NaN  297226.0       NaN  273187.0       NaN  260387.0  240810.0       NaN  241022.0  236376.0
# 1988  363266.0       NaN  364326.0       NaN  352822.0       NaN  328256.0  297773.0       NaN  279108.0       NaN  265990.0       NaN  254703.0  245846.0       NaN       NaN
# 1989  421814.0       NaN  415173.0       NaN       NaN  390700.0  351752.0  327502.0       NaN  309818.0       NaN       NaN  296474.0  280411.0       NaN       NaN       NaN
# 1990  459573.0       NaN       NaN  440929.0       NaN  412603.0  391085.0  372147.0       NaN       NaN  346853.0       NaN  330443.0       NaN       NaN       NaN       NaN
# 1991       NaN  519397.0       NaN  493296.0       NaN  444814.0  417376.0       NaN  395223.0       NaN  361505.0       NaN       NaN       NaN       NaN       NaN       NaN
# 1992  510705.0       NaN  474444.0       NaN  455989.0       NaN  428346.0  409466.0       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1993  536609.0       NaN  518333.0       NaN       NaN  507586.0  467341.0       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1994  562089.0       NaN       NaN  554926.0       NaN  525577.0       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1995       NaN  560248.0       NaN  543519.0       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1996  536705.0       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1997       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN

# %%
import pandas as pd
from formulaic import Formula as fm
import glum

# Sample dataset creation (you'd load your actual data)
insurance_data = pd.DataFrame({
    'claim_amount': [1000, 5000, 3500, 800, 1200, ...],
    'development_year': [1, 1, 2, 1, 3, ...], 
    'origin_year': [2022, 2021, 2022, 2021, 2020, ...] 
})

# Formula Specification
model_formula = fm('claim_amount ~ development_year + origin_year + development_year:origin_year')

# GLM model fitting
model = glum.GeneralizedLinearRegressor(family="twedie", link='log')
model = model.fit(data=insurance_data, formula=model_formula)

# Predictions and further analysis
predictions = model.predict(insurance_data) 
print(model.summary())  # View model summary
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/glum/_glm.py:2776: FutureWarning: The default value of `alpha` will become `0` in 3.0.0.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 17
#      15 # GLM model fitting
#      16 model = glum.GeneralizedLinearRegressor(family="twedie", link='log')
# ---> 17 model = model.fit(data=insurance_data, formula=model_formula)
#      19 # Predictions and further analysis
#      20 predictions = model.predict(insurance_data)
#
# File ~/.local/lib/python3.10/site-packages/glum/_util.py:141, in _positional_args_deprecated.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     136 if len(args) > unchanged_args_number + 1:  # +1 for self
#     137     warnings.warn(
#     138         msg,
#     139         FutureWarning,
#     140     )
# --> 141 return func(*args, **kwargs)
#
# TypeError: GeneralizedLinearRegressor.fit() got an unexpected keyword argument 'data'
